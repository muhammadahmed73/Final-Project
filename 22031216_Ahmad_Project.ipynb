# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadahmed73/Final-Project/blob/main/22031216_Ahmad_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/Final Project/Big_Black_Money_Dataset.csv")
df.head()
# Out:
#   Transaction ID       Country  Amount (USD)   Transaction Type  \
# 0   TX0000000001        Brazil  3.267530e+06  Offshore Transfer
# 1   TX0000000002         China  4.965767e+06    Stocks Transfer
# 2   TX0000000003            UK  9.416750e+04    Stocks Transfer
# 3   TX0000000004           UAE  3.864201e+05    Cash Withdrawal
# 4   TX0000000005  South Africa  6.433784e+05     Cryptocurrency
#
#    Date of Transaction Person Involved      Industry Destination Country  \
# 0  2013-01-01 00:00:00     Person_1101  Construction                 USA
# 1  2013-01-01 01:00:00     Person_7484  Luxury Goods        South Africa
# 2  2013-01-01 02:00:00     Person_3655  Construction         Switzerland
# 3  2013-01-01 03:00:00     Person_3226     Oil & Gas              Russia
# 4  2013-01-01 04:00:00     Person_7975   Real Estate                 USA
#
#    Reported by Authority Source of Money  Money Laundering Risk Score  \
# 0                   True         Illegal                            6
# 1                  False         Illegal                            9
# 2                   True         Illegal                            1
# 3                  False         Illegal                            7
# 4                   True         Illegal                            1
#
#    Shell Companies Involved Financial Institution Tax Haven Country
# 0                         1               Bank_40         Singapore
# 1                         0              Bank_461           Bahamas
# 2                         3              Bank_387       Switzerland
# 3                         2              Bank_353            Panama
# 4                         9               Bank_57        Luxembourg

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Country', 'Amount (USD)', 'Transaction Type',
#        'Date of Transaction', 'Person Involved', 'Industry',
#        'Destination Country', 'Reported by Authority', 'Source of Money',
#        'Money Laundering Risk Score', 'Shell Companies Involved',
#        'Financial Institution', 'Tax Haven Country'],
#       dtype='object')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# Getting data information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Transaction ID               10000 non-null  object
#  1   Country                      10000 non-null  object
#  2   Amount (USD)                 10000 non-null  float64
#  3   Transaction Type             10000 non-null  object
#  4   Date of Transaction          10000 non-null  object
#  5   Person Involved              10000 non-null  object
#  6   Industry                     10000 non-null  object
#  7   Destination Country          10000 non-null  object
#  8   Reported by Authority        10000 non-null  bool
#  9   Source of Money              10000 non-null  object
#  10  Money Laundering Risk Score  10000 non-null  int64
#  11  Shell Companies Involved     10000 non-null  int64
#  12  Financial Institution        10000 non-null  object
#  13  Tax Haven Country            10000 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(10)
# memory usage: 1.0+ MB

# %%
df.dtypes
# Out:
# Transaction ID                  object
# Country                         object
# Amount (USD)                   float64
# Transaction Type                object
# Date of Transaction             object
# Person Involved                 object
# Industry                        object
# Destination Country             object
# Reported by Authority             bool
# Source of Money                 object
# Money Laundering Risk Score      int64
# Shell Companies Involved         int64
# Financial Institution           object
# Tax Haven Country               object
# dtype: object

# %% [markdown]
# Changing the datatype to suitable formats

# %%
columns_to_convert = ['Transaction ID', 'Country', 'Transaction Type', 'Person Involved', 'Industry',
                      'Destination Country', 'Source of Money', 'Financial Institution', 'Tax Haven Country']
df[columns_to_convert] = df[columns_to_convert].astype('string')

# %% [markdown]
# Making a date type of the datee format which currently exists in object format

# %%
df['Date of Transaction'] = pd.to_datetime(df['Date of Transaction'])

# %%
df["Amount (USD)"] = df["Amount (USD)"].astype('float')

# %%
# Country
# Amount
# Transaction Type
# Date of Transaction

# Destination Country
# Source of Money

# %%
df
# Out:
#      Transaction ID       Country  Amount (USD)   Transaction Type  \
# 0      TX0000000001        Brazil  3.267530e+06  Offshore Transfer
# 1      TX0000000002         China  4.965767e+06    Stocks Transfer
# 2      TX0000000003            UK  9.416750e+04    Stocks Transfer
# 3      TX0000000004           UAE  3.864201e+05    Cash Withdrawal
# 4      TX0000000005  South Africa  6.433784e+05     Cryptocurrency
# ...             ...           ...           ...                ...
# 9995   TX0000009996     Singapore  2.209229e+06  Offshore Transfer
# 9996   TX0000009997           UAE  4.800338e+06  Property Purchase
# 9997   TX0000009998            UK  4.891953e+05    Stocks Transfer
# 9998   TX0000009999        Brazil  2.233581e+06  Offshore Transfer
# 9999   TX0000010000   Switzerland  3.846778e+05    Stocks Transfer
#
#      Date of Transaction Person Involved      Industry Destination Country  \
# 0    2013-01-01 00:00:00     Person_1101  Construction                 USA
# 1    2013-01-01 01:00:00     Person_7484  Luxury Goods        South Africa
# 2    2013-01-01 02:00:00     Person_3655  Construction         Switzerland
# 3    2013-01-01 03:00:00     Person_3226     Oil & Gas              Russia
# 4    2013-01-01 04:00:00     Person_7975   Real Estate                 USA
# ...                  ...             ...           ...                 ...
# 9995 2014-02-21 11:00:00     Person_6896   Real Estate              Brazil
# 9996 2014-02-21 12:00:00     Person_6348  Luxury Goods              Russia
# 9997 2014-02-21 13:00:00     Person_4171     Oil & Gas              Russia
# 9998 2014-02-21 14:00:00     Person_2799   Real Estate              Russia
# 9999 2014-02-21 15:00:00     Person_3267    Arms Trade               China
#
#       Reported by Authority Source of Money  Money Laundering Risk Score  \
# 0                      True         Illegal                            6
# 1                     False         Illegal                            9
# 2                      True         Illegal                            1
# 3                     False         Illegal                            7
# 4                      True         Illegal                            1
# ...                     ...             ...                          ...
# 9995                  False         Illegal                            4
# 9996                  False           Legal                           10
# 9997                  False         Illegal                            5
# 9998                   True         Illegal                           10
# 9999                   True           Legal                            5
#
#       Shell Companies Involved Financial Institution Tax Haven Country
# 0                            1               Bank_40         Singapore
# 1                            0              Bank_461           Bahamas
# 2                            3              Bank_387       Switzerland
# 3                            2              Bank_353            Panama
# 4                            9               Bank_57        Luxembourg
# ...                        ...                   ...               ...
# 9995                         4              Bank_258        Luxembourg
# 9996                         2              Bank_449        Luxembourg
# 9997                         0              Bank_156    Cayman Islands
# 9998                         5               Bank_12         Singapore
# 9999                         4               Bank_22            Panama
#
# [10000 rows x 14 columns]

# %% [markdown]
# Updated dataframe types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Transaction ID               10000 non-null  string
#  1   Country                      10000 non-null  string
#  2   Amount (USD)                 10000 non-null  float64
#  3   Transaction Type             10000 non-null  string
#  4   Date of Transaction          10000 non-null  datetime64[ns]
#  5   Person Involved              10000 non-null  string
#  6   Industry                     10000 non-null  string
#  7   Destination Country          10000 non-null  string
#  8   Reported by Authority        10000 non-null  bool
#  9   Source of Money              10000 non-null  string
#  10  Money Laundering Risk Score  10000 non-null  int64
#  11  Shell Companies Involved     10000 non-null  int64
#  12  Financial Institution        10000 non-null  string
#  13  Tax Haven Country            10000 non-null  string
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(2), string(9)
# memory usage: 1.0 MB

# %% [markdown]
# Checking null values

# %%
df.isnull().sum()
# Out:
# Transaction ID                 0
# Country                        0
# Amount (USD)                   0
# Transaction Type               0
# Date of Transaction            0
# Person Involved                0
# Industry                       0
# Destination Country            0
# Reported by Authority          0
# Source of Money                0
# Money Laundering Risk Score    0
# Shell Companies Involved       0
# Financial Institution          0
# Tax Haven Country              0
# dtype: int64

# %% [markdown]
# There are currently no null values in our dataset

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
country_counts = df['Country'].value_counts().sort_values(ascending=False)
color = "#%06x" % random.randint(0, 0xFFFFFF)

plt.figure(figsize=(10, 6))
sns.barplot(x=country_counts.index, y=country_counts.values, color=color)
plt.xticks(rotation=45)
plt.title("The origin countries for the most illegal money laundering")
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %%
country_counts = df['Destination Country'].value_counts().sort_values(ascending=False)
color = "#%06x" % random.randint(0, 0xFFFFFF)
plt.figure(figsize=(10, 6))
sns.barplot(x=country_counts.index, y=country_counts.values, color=color)
plt.xticks(rotation=45)
plt.title("The destination countries for the most illegal money laundering")
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %%
country_counts = df['Industry'].value_counts().sort_values(ascending=False)
color = "#%06x" % random.randint(0, 0xFFFFFF)
# Create the plot
plt.figure(figsize=(10, 6))
sns.barplot(x=country_counts.index, y=country_counts.values, color=color)
plt.xticks(rotation=45)
plt.title("The industries involved for the most illegal money laundering")
plt.xlabel("Industry")
plt.ylabel("Count")
plt.show()

# %%
country_counts = df['Source of Money'].value_counts().sort_values(ascending=False)
color = "#%06x" % random.randint(0, 0xFFFFFF)
plt.figure(figsize=(10, 6))
sns.barplot(x=country_counts.index, y=country_counts.values, color=color)
plt.xticks(rotation=45)
plt.title("The Transaction Types used for the most illegal money laundering")
plt.xlabel("Industry")
plt.ylabel("Count")
plt.show()

# %%
# Sort the DataFrame by "Money Laundering Risk Score" for ascending hue order
df_sorted = df.sort_values(by="Money Laundering Risk Score")

# Generate moderately light colors (values between 150 and 220 for each RGB component)
hue_categories = df_sorted["Money Laundering Risk Score"].nunique()
balanced_colors = ["#%02x%02x%02x" % (random.randint(100, 200), random.randint(100, 200), random.randint(100, 200)) for _ in range(hue_categories)]

# Create the plot
plt.figure(figsize=(10, 6))
sns.countplot(data=df_sorted, x="Source of Money", hue="Money Laundering Risk Score", palette=balanced_colors)
plt.xticks(rotation=45)
plt.title("Count of Source of Money")
plt.xlabel("Source of Money")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# The plot shows the distribution of different sources of money, with varying risk scores (1 to 10), allowing for a visual assessment of the risk associated with each source.
# I can observe which money sources are more likely to be associated with high-risk money laundering activities. Higher risk sources could guide authorities to focus their monitoring efforts.

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# import matplotlib.dates as mdates

# small_df = df[df['Country'] == 'China']

# plt.figure(figsize=(20, 6))
# sns.lineplot(data=small_df, x='Date of Transaction', y='Amount (USD)', hue='Destination Country')
# plt.title("Transaction Amount Over Time from China")
# plt.xlabel("Date of Transaction")
# plt.ylabel("Amount (USD)")
# plt.xticks(rotation=45)
# plt.show()

# %%
# Generate random colors for each hue category
hue_categories = df["Reported by Authority"].nunique()
colors = ["#%06x" % random.randint(0, 0xFFFFFF) for _ in range(hue_categories)]

# Create the plot
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="Source of Money", hue="Reported by Authority", palette=colors)
plt.xticks(rotation=45)
plt.title("Count of Source of Money by Reported Authority")
plt.xlabel("Source of Money")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# The chart shows that the majority of illegal transactions are not reported to authorities.
# This emphasizes a key issue in the fight against money laundering: a significant portion of illicit transactions is not flagged or reported by institutions, which might allow suspicious activities to continue undetected.

# %%
# Distribution of transaction amounts
plt.figure(figsize=(12, 6))
sns.histplot(df['Amount (USD)'], bins=50, kde=True, color='blue')
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Amount (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Money Laundering Risk Analysis**

# %%
# Extracting key columns for analysis
risk_analysis_columns = [
    "Amount (USD)",
    "Money Laundering Risk Score",
    "Shell Companies Involved"
]

# Calculating correlation matrix for these columns
correlation_matrix = df[risk_analysis_columns].corr()

# %%
# Visualizing the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar=True)
plt.title("Correlation Matrix of Risk Factors", fontsize=14, weight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# The heatmap reveals that there is very little correlation between the variables Amount (USD), Money Laundering Risk Score, and Shell Companies Involved. This suggests that these features do not have a strong direct relationship with each other in the context of your dataset.

# %%
# Plotting distributions of Money Laundering Risk Score by key factors
# Shell Companies vs Risk Score
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="Shell Companies Involved", y="Money Laundering Risk Score", palette="viridis")
plt.title("Shell Companies Involved vs Money Laundering Risk Score", fontsize=14, weight='bold')
plt.xlabel("Number of Shell Companies Involved", fontsize=12)
plt.ylabel("Money Laundering Risk Score", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-25-e626110f0a01>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Shell Companies Involved", y="Money Laundering Risk Score", palette="viridis")

# %% [markdown]
# The plot shows that the Money Laundering Risk Score remains relatively consistent across different numbers of shell companies involved, with a slight increase in risk scores when 5 or more shell companies are involved.
# Insight: This suggests that the number of shell companies involved does not drastically affect the money laundering risk score, though there is a slight upward trend in risk with more shell companies.

# %%
# Transaction Amount vs Risk Score
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="Amount (USD)", y="Money Laundering Risk Score", alpha=0.6, hue="Money Laundering Risk Score", palette="coolwarm")
plt.title("Transaction Amount vs Money Laundering Risk Score", fontsize=14, weight='bold')
plt.xlabel("Transaction Amount (USD)", fontsize=12)
plt.ylabel("Money Laundering Risk Score", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Larger transactions do not necessarily correlate with higher money laundering risk, indicating that the amount alone is not a reliable factor for predicting the risk of money laundering.

# %%
df['Transaction Type'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140, colors=sns.color_palette('husl', n_colors=df['Transaction Type'].nunique()))
plt.title('Distribution of Transaction Types')
plt.ylabel('')
plt.show()

# %% [markdown]
# The distribution of transaction types is almost evenly spread across the five transaction types: Cryptocurrency, Property Purchase, Offshore Transfer, Cash Withdrawal, and Stocks Transfer, with each type around 19-21%.
#
# This indicates that there is no dominant transaction type in this dataset, and the illegal financial activities are distributed across various transaction methods.

# %%
df['Source of Money'].unique()
# Out:
# <StringArray>
# ['Illegal', 'Legal']
# Length: 2, dtype: string

# %%
# how black money is moved
df_sub = df[df['Source of Money']=="Illegal"]


plt.figure(figsize=(10, 8))
df_sub['Transaction Type'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140, colors=sns.color_palette('husl', n_colors=df_sub['Transaction Type'].nunique()))
plt.title('Major transaction types in illegal money movement')
plt.ylabel('')
plt.show()

# %% [markdown]
# The chart reveals that illegal transactions are distributed similarly to all transactions. However, the proportion of Property Purchase and Cryptocurrency seems slightly higher.
#
# These two transaction types play a significant role in illegal money movements, suggesting that these methods might be frequently used to launder money.

# %%
# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# Pie chart for illegal money
df_sub['Transaction Type'].value_counts().plot.pie(
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette('husl', n_colors=df_sub['Transaction Type'].nunique()),
    ax=axes[0]
)
axes[0].set_title('Illegal Money - Transaction Types')
axes[0].set_ylabel('')

# Pie chart for legal money
order = df_sub["Destination Country"].value_counts(ascending=False).index
# Create the countplot with the sorted order
sns.countplot(data=df_sub, y="Destination Country", order=order)
axes[1].set_title('Countries involved in illegal transaction')
axes[1].set_ylabel('')

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# The USA and India are key players in illegal money movement. The bar chart helps identify which countries are involved in the most illicit financial activities.

# %%
df_sub
# Out:
#      Transaction ID       Country  Amount (USD)   Transaction Type  \
# 0      TX0000000001        Brazil  3.267530e+06  Offshore Transfer
# 1      TX0000000002         China  4.965767e+06    Stocks Transfer
# 2      TX0000000003            UK  9.416750e+04    Stocks Transfer
# 3      TX0000000004           UAE  3.864201e+05    Cash Withdrawal
# 4      TX0000000005  South Africa  6.433784e+05     Cryptocurrency
# ...             ...           ...           ...                ...
# 9991   TX0000009992   Switzerland  1.679869e+06    Cash Withdrawal
# 9993   TX0000009994        Russia  3.886784e+06     Cryptocurrency
# 9995   TX0000009996     Singapore  2.209229e+06  Offshore Transfer
# 9997   TX0000009998            UK  4.891953e+05    Stocks Transfer
# 9998   TX0000009999        Brazil  2.233581e+06  Offshore Transfer
#
#      Date of Transaction Person Involved      Industry Destination Country  \
# 0    2013-01-01 00:00:00     Person_1101  Construction                 USA
# 1    2013-01-01 01:00:00     Person_7484  Luxury Goods        South Africa
# 2    2013-01-01 02:00:00     Person_3655  Construction         Switzerland
# 3    2013-01-01 03:00:00     Person_3226     Oil & Gas              Russia
# 4    2013-01-01 04:00:00     Person_7975   Real Estate                 USA
# ...                  ...             ...           ...                 ...
# 9991 2014-02-21 07:00:00     Person_9785  Luxury Goods        South Africa
# 9993 2014-02-21 09:00:00     Person_4031  Luxury Goods               India
# 9995 2014-02-21 11:00:00     Person_6896   Real Estate              Brazil
# 9997 2014-02-21 13:00:00     Person_4171     Oil & Gas              Russia
# 9998 2014-02-21 14:00:00     Person_2799   Real Estate              Russia
#
#       Reported by Authority Source of Money  Money Laundering Risk Score  \
# 0                      True         Illegal                            6
# 1                     False         Illegal                            9
# 2                      True         Illegal                            1
# 3                     False         Illegal                            7
# 4                      True         Illegal                            1
# ...                     ...             ...                          ...
# 9991                  False         Illegal                            1
# 9993                  False         Illegal                            1
# 9995                  False         Illegal                            4
# 9997                  False         Illegal                            5
# 9998                   True         Illegal                           10
#
#       Shell Companies Involved Financial Institution Tax Haven Country
# 0                            1               Bank_40         Singapore
# 1                            0              Bank_461           Bahamas
# 2                            3              Bank_387       Switzerland
# 3                            2              Bank_353            Panama
# 4                            9               Bank_57        Luxembourg
# ...                        ...                   ...               ...
# 9991                         9              Bank_196           Bahamas
# 9993                         7              Bank_251    Cayman Islands
# 9995                         4              Bank_258        Luxembourg
# 9997                         0              Bank_156    Cayman Islands
# 9998                         5               Bank_12         Singapore
#
# [7017 rows x 14 columns]

# %%
plt.figure(figsize=(10, 8))
df['Industry'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140, colors=sns.color_palette('husl', n_colors=df['Industry'].nunique()))
plt.title('Distribution of Industry')
plt.ylabel('')
plt.show()

# %% [markdown]
# The industries are more equally distributed, but Oil & Gas and Casinos stand out as major contributors to illegal money laundering activities.
#
# Certain industries, particularly Oil & Gas and Casinos, are more prone to illegal money laundering, possibly due to their complex financial operations or high cash flow activities.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_style("whitegrid")

# Sort the DataFrame by "Money Laundering Risk Score" for ascending hue order
df_sorted = df.sort_values(by="Money Laundering Risk Score")

# Use a predefined color palette for a more cohesive look
palette = sns.color_palette("Spectral", df_sorted["Money Laundering Risk Score"].nunique())

# Create the plot
plt.figure(figsize=(12, 8))
sns.countplot(data=df_sorted, y="Destination Country", hue="Money Laundering Risk Score", palette=palette)
plt.title("Distribution of Money Laundering Risk Score by Destination Country", fontsize=14, weight='bold')
plt.xlabel("Count", fontsize=12)
plt.ylabel("Destination Country", fontsize=12)

# Add a legend title
plt.legend(title="Money Laundering Risk Score", title_fontsize='13', fontsize='11')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# The first plot is a horizontal bar plot showing the distribution of money laundering risk scores by Destination Country.
#
# The second plot is a boxplot showing the spread of money laundering risk scores across countries
#
# The USA and South Africa show a greater number of high-risk transactions, and the spread in risk scores across countries indicates varying degrees of money laundering activity. The UAE, with a narrower spread, could suggest more consistent money laundering behavior.

# %%
import matplotlib.pyplot as plt
# Set plot style
sns.set_style("whitegrid")
# Create the box plot
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x="Destination Country", y="Money Laundering Risk Score", palette="Spectral")
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.title("Distribution of Money Laundering Risk Score by Destination Country", fontsize=14, weight='bold')
plt.xlabel("Destination Country", fontsize=12)
plt.ylabel("Money Laundering Risk Score", fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-4663925ceeaf>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Destination Country", y="Money Laundering Risk Score", palette="Spectral")

# %% [markdown]
# Risk Concentration:
#
# USA, South Africa, and Switzerland have a higher concentration of higher risk scores (close to 8-9), suggesting that these countries are often involved in higher-risk money laundering activities.
#
# UAE has a lower spread, suggesting it may involve transactions with more consistent, possibly lower, money laundering risk.
# Spread of Risk Scores:
#
# UAE and Singapore appear to have less variability in the risk scores, with the boxplot showing smaller interquartile ranges, which could mean that transactions in these countries tend to be less risky overall compared to others.
#
# The USA and South Africa have wider ranges, showing more variability in the risk scores.

# %%
# Aggregate data to get the total amount for each financial institution and destination country
total_amounts = df.groupby(['Financial Institution', 'Destination Country'])['Amount (USD)'].sum().reset_index()

# Get the top 5 financial institutions with the highest amounts
top_banks = total_amounts.groupby('Financial Institution')['Amount (USD)'].sum().nlargest(5).index

# Filter to keep only the rows for these top banks
top_banks_data = total_amounts[total_amounts['Financial Institution'].isin(top_banks)]

# Create a bar plot for the top banks and their destination countries
plt.figure(figsize=(18, 9))
sns.barplot(data=top_banks_data, x='Financial Institution', y='Amount (USD)', hue='Destination Country', palette='Paired')

# Plot aesthetics
plt.title('Top 5 Banks with Highest Amount Transferred and their Destination Country', fontsize=16, weight='bold')
plt.xlabel('Financial Institution', fontsize=12)
plt.ylabel('Total Amount Transferred (USD)', fontsize=12)
plt.xticks(rotation=45)

# Set y-axis to display without scientific notation
plt.ticklabel_format(style='plain', axis='y')

# Adjust layout and show plot
plt.tight_layout()
plt.legend(title='Destination Country')
plt.show()

# %% [markdown]
# Banks with High Transaction Volume: Bank_164 stands out as the bank handling the highest volume of transfers. It has several countries as key destinations, with the USA, China, and Brazil being prominent.
#
# Countries of Transfer: The chart helps identify countries involved in illegal or high-risk money transfers, with major countries like USA, China, Brazil, and South Africa being consistently present across the top banks.
#
# Destination Country Trends: By visualizing the destination country for each financial institution, you can identify global trends in money transfers. It highlights the importance of regions like South Africa, USA, and China in money laundering activities.

# %%
# Aggregate data to get the total amount for each financial institution and destination country
total_amounts = df.groupby(['Financial Institution', 'Transaction Type'])['Amount (USD)'].sum().reset_index()

# Get the top 5 financial institutions with the highest amounts
top_banks = total_amounts.groupby('Financial Institution')['Amount (USD)'].sum().nlargest(5).index

# Filter to keep only the rows for these top banks
top_banks_data = total_amounts[total_amounts['Financial Institution'].isin(top_banks)]

# Create a bar plot for the top banks and their destination countries
plt.figure(figsize=(18, 9))
sns.barplot(data=top_banks_data, x='Financial Institution', y='Amount (USD)', hue='Transaction Type', palette='Paired')

# Plot aesthetics
plt.title('Top 5 Banks with Highest Amount Transferred and their Transaction Types', fontsize=16, weight='bold')
plt.xlabel('Financial Institution', fontsize=12)
plt.ylabel('Total Amount Transferred (USD)', fontsize=12)
plt.xticks(rotation=45)

# Set y-axis to display without scientific notation
plt.ticklabel_format(style='plain', axis='y')

# Adjust layout and show plot
plt.tight_layout()
plt.legend(title='Transaction Types')
plt.show()

# %% [markdown]
# Bank_164 stands out as the bank with the highest total amount transferred, with the largest share coming from Offshore Transfers and Cash Withdrawals.
#
# Bank_428 also shows significant transfers, especially in Offshore Transfers.
#
# Bank_81 has relatively balanced transfers across different types of transactions, with Stocks Transfer showing a notable portion.
#
# Bank_260 and Bank_24 show a more even distribution across the transaction types, though Bank_260 has a higher share of Cryptocurrency.

# %%
# Convert 'Date of Transaction' to datetime
df['Date of Transaction'] = pd.to_datetime(df['Date of Transaction'])

# Add a column for the month and quarter
df['Month'] = df['Date of Transaction'].dt.month
df['Quarter'] = df['Date of Transaction'].dt.to_period('Q')

# Create a figure with subplots for each quarter
fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharey=True)
axes = axes.flatten()  # Flatten to easily access each subplot

# Define quarters for labeling
quarters = ['2013Q1', '2013Q2', '2013Q3', '2013Q4']

for i, quarter in enumerate(quarters):
    # Filter data for each quarter
    quarter_data = df[df['Quarter'] == quarter]

    # Calculate monthly averages for each month in the quarter
    monthly_avg = quarter_data.groupby(['Month'])['Amount (USD)'].mean().reset_index()

    # Create the plot for the quarter
    sns.barplot(data=monthly_avg, x='Month', y='Amount (USD)', ax=axes[i], palette='viridis')

    # Plot aesthetics
    axes[i].set_title(f'Average Amount (USD) for {quarter}', fontsize=14, weight='bold')
    axes[i].set_xlabel('Month', fontsize=12)
    axes[i].set_ylabel('Average Amount (USD)', fontsize=12)
    # axes[i].set_xticks(range(1, 13))  # Set x-ticks to represent months
    # axes[i].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
    # axes[i].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()
plt.suptitle('Monthly Average Amounts by Quarter (2013)', fontsize=16, weight='bold', y=1.02)
plt.show()
# Out:
# <ipython-input-38-2ea193290dda>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly_avg, x='Month', y='Amount (USD)', ax=axes[i], palette='viridis')
# <ipython-input-38-2ea193290dda>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly_avg, x='Month', y='Amount (USD)', ax=axes[i], palette='viridis')
# <ipython-input-38-2ea193290dda>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly_avg, x='Month', y='Amount (USD)', ax=axes[i], palette='viridis')
# <ipython-input-38-2ea193290dda>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly_avg, x='Month', y='Amount (USD)', ax=axes[i], palette='viridis')

# %% [markdown]
# Interpretation:
#
# The monthly average amounts for each quarter of 2013 are plotted in individual bar plots for each quarter.
#
# For each quarter (Q1, Q2, Q3, Q4), the monthly data is presented, showing a consistent amount transferred across the months in each quarter, without significant fluctuations.
#
# Insights:
#
# Consistency: There is little variation in the average amount transferred across months in each quarter, suggesting a steady flow of transactions throughout the year.
#
# The average amount transferred in each month of a quarter is almost the same for each quarter (2013Q1 to 2013Q4), with the data showing no major peaks or drops.
#
# This could indicate stable financial activities in terms of transaction amounts during 2013, with no significant fluctuations in the transfer amounts month by month.

# %%
# Convert 'Date of Transaction' to datetime
df['Date of Transaction'] = pd.to_datetime(df['Date of Transaction'])

# Add a column for the month
df['Month'] = df['Date of Transaction'].dt.month

# Calculate monthly averages
monthly_avg = df.groupby(['Month'])['Amount (USD)'].mean().reset_index()

# Create a single plot for monthly averages
plt.figure(figsize=(10, 6))
sns.lineplot(data=monthly_avg, x='Month', y='Amount (USD)', marker='o', palette='viridis')

# Plot aesthetics
plt.title('Average Amount (USD) by Month (2013)', fontsize=14, weight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Average Amount (USD)', fontsize=12)
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)

# Adjust layout and show plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-39-528dc13e2ab4>:12: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=monthly_avg, x='Month', y='Amount (USD)', marker='o', palette='viridis')

# %% [markdown]
# The highest amount transferred was observed in April and September, with a noticeable dip in July.
#
# The average amount seems to generally fluctuate around the range of 2.46 million USD to 2.54 million USD.
#
# The decline in July is quite sharp, suggesting a potential anomaly or significant reduction in transactions for that month.
#
# Consistency is observed in June, August, and December, where the average transaction amounts are relatively stable.

# %%
# Convert 'Date of Transaction' to datetime
df['Date of Transaction'] = pd.to_datetime(df['Date of Transaction'])

# Add a column for the month
df['Month'] = df['Date of Transaction'].dt.month

# Calculate monthly averages grouped by Month and Industry
monthly_avg = df.groupby(['Month', 'Industry'])['Amount (USD)'].mean().reset_index()

# Create a single plot for monthly averages with hue
plt.figure(figsize=(18, 8))
sns.lineplot(data=monthly_avg, x='Month', y='Amount (USD)', marker='o', hue='Industry', palette='Set2', linewidth=2)

# Plot aesthetics
plt.title('Average Amount (USD) by Month (2013) with Industry Hue', fontsize=14, weight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Average Amount (USD)', fontsize=12)
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)

# Adjust layout and show plot
plt.tight_layout()
plt.legend(title='Industry')
plt.show()

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Country', 'Amount (USD)', 'Transaction Type',
#        'Date of Transaction', 'Person Involved', 'Industry',
#        'Destination Country', 'Reported by Authority', 'Source of Money',
#        'Money Laundering Risk Score', 'Shell Companies Involved',
#        'Financial Institution', 'Tax Haven Country', 'Month', 'Quarter'],
#       dtype='object')

# %%
# Convert 'Date of Transaction' to datetime
df['Date of Transaction'] = pd.to_datetime(df['Date of Transaction'])

# Add a column for the month
df['Month'] = df['Date of Transaction'].dt.month

# Calculate monthly averages grouped by Month and Industry
monthly_avg = df.groupby(['Month', 'Destination Country'])['Amount (USD)'].mean().reset_index()

# Create a single plot for monthly averages with hue
plt.figure(figsize=(18, 8))
sns.lineplot(data=monthly_avg, x='Month', y='Amount (USD)', marker='o', hue='Destination Country', palette='Dark2', linewidth=2.5)

# Plot aesthetics
plt.title('Average Amount (USD) by Month (2013) with Destination Country Hue', fontsize=14, weight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Average Amount (USD)', fontsize=12)
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)

# Adjust layout and show plot
plt.tight_layout()
plt.legend(title='Industry')
plt.show()

# %%
# Convert 'Date of Transaction' to datetime
df['Date of Transaction'] = pd.to_datetime(df['Date of Transaction'])

# Add a column for the month
df['Month'] = df['Date of Transaction'].dt.month

# Calculate monthly averages grouped by Month and Industry
monthly_avg = df.groupby(['Month', 'Reported by Authority'])['Amount (USD)'].mean().reset_index()

# Create a single plot for monthly averages with hue
plt.figure(figsize=(18, 8))
sns.lineplot(data=monthly_avg, x='Month', y='Amount (USD)', marker='o', hue='Reported by Authority', palette='Dark2', linewidth=2.5)

# Plot aesthetics
plt.title('Average Amount (USD) by Month (2013) with Reported by Authority', fontsize=14, weight='bold')
plt.xlabel('Month', fontsize=12)
plt.ylabel('Average Amount (USD)', fontsize=12)
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)

# Adjust layout and show plot
plt.tight_layout()
plt.legend(title='Industry')
plt.show()

# %% [markdown]
# The line plot shows the average amount (USD) for each month of 2013, comparing whether the transactions were reported by authority (True) or not reported (False).
# There is a clear pattern showing that the reported transactions (True) tend to have higher average amounts compared to the non-reported transactions (False).
#
# March and November have significant spikes in the average amount for reported transactions, with March showing a notable peak for reported transactions.
#
# June stands out with a sharp dip in reported transactions, suggesting a drastic drop in the average amount during this period.
#
# For non-reported transactions, the values are more consistent, but still lower than the reported transactions overall, with slight fluctuations throughout the year.

# %% [markdown]
# #**Feature Importance Analysis: Use machine learning models (e.g., Random Forest) to identify the most impactful features for predicting risk.**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
# Selecting relevant features and the target variable
features = [
    "Amount (USD)",
    "Shell Companies Involved",
    "Transaction Type",
    "Country",
    "Destination Country",
    "Tax Haven Country"
]
target = "Money Laundering Risk Score"

# %%
# Encoding categorical variables using LabelEncoder
label_encoders = {}
for col in ["Transaction Type", "Country", "Destination Country", "Tax Haven Country"]:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
# Splitting the data into training and testing sets
X = df[features]
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Training a Random Forest model
rf_model = RandomForestClassifier(random_state=42, n_estimators=100)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# The Random Forest model is used here to analyze feature importance for predicting the Money Laundering Risk Score. By training the model, we can identify which features contribute the most in determining the risk score. The most important features can be determined by checking the feature importances from the trained model.

# %%
# Extracting feature importances
feature_importances = rf_model.feature_importances_

# Creating a DataFrame for feature importance visualization
importance_df = pd.DataFrame({
    "Feature": features,
    "Importance": feature_importances
}).sort_values(by="Importance", ascending=False)

# %%
# Plotting feature importances
plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df, x="Importance", y="Feature", palette="viridis")
plt.title("Feature Importance for Predicting Money Laundering Risk", fontsize=14, weight='bold')
plt.xlabel("Importance", fontsize=12)
plt.ylabel("Feature", fontsize=12)
plt.tight_layout()
plt.show()

importance_df
# Out:
# <ipython-input-52-d3dfc979c706>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=importance_df, x="Importance", y="Feature", palette="viridis")
#                     Feature  Importance
# 0              Amount (USD)    0.330802
# 4       Destination Country    0.161096
# 1  Shell Companies Involved    0.149669
# 3                   Country    0.142247
# 5         Tax Haven Country    0.112240
# 2          Transaction Type    0.103946

# %% [markdown]
# Key Insights:
# Amount (USD) is the most important feature for predicting the Money Laundering Risk Score with an importance of 0.3308.
# The Destination Country follows closely with an importance of 0.1611.
# Shell Companies Involved also plays a significant role, with an importance of 0.1469.
# Transaction Type, Country, and Tax Haven Country are relatively less impactful compared to the top three.

# %% [markdown]
# # Model Development

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
# Extract date features
df['Year'] = df['Date of Transaction'].dt.year
df['Month'] = df['Date of Transaction'].dt.month
df['Day'] = df['Date of Transaction'].dt.day
df['Weekday'] = df['Date of Transaction'].dt.weekday

# %%
columns = ['Country', 'Amount (USD)' ,'Transaction Type', 'Date of Transaction', 'Destination Country','Source of Money', 'Reported by Authority']
df_mapped = df[columns]

# %%
df_mapped
# Out:
#       Country  Amount (USD)  Transaction Type Date of Transaction  \
# 0           0  3.267530e+06                 2 2013-01-01 00:00:00
# 1           1  4.965767e+06                 4 2013-01-01 01:00:00
# 2           8  9.416750e+04                 4 2013-01-01 02:00:00
# 3           7  3.864201e+05                 0 2013-01-01 03:00:00
# 4           5  6.433784e+05                 1 2013-01-01 04:00:00
# ...       ...           ...               ...                 ...
# 9995        4  2.209229e+06                 2 2014-02-21 11:00:00
# 9996        7  4.800338e+06                 3 2014-02-21 12:00:00
# 9997        8  4.891953e+05                 4 2014-02-21 13:00:00
# 9998        0  2.233581e+06                 2 2014-02-21 14:00:00
# 9999        6  3.846778e+05                 4 2014-02-21 15:00:00
#
#       Destination Country Source of Money  Reported by Authority
# 0                       9         Illegal                   True
# 1                       5         Illegal                  False
# 2                       6         Illegal                   True
# 3                       3         Illegal                  False
# 4                       9         Illegal                   True
# ...                   ...             ...                    ...
# 9995                    0         Illegal                  False
# 9996                    3           Legal                  False
# 9997                    3         Illegal                  False
# 9998                    3         Illegal                   True
# 9999                    1           Legal                   True
#
# [10000 rows x 7 columns]

# %%
def map_strings_to_numbers(df, columns):
    """
    Maps strings to unique numbers for the specified columns in a DataFrame.

    Parameters:
        df (pd.DataFrame): The input DataFrame.
        columns (list): A list of column names to map strings to numbers.

    Returns:
        pd.DataFrame: The modified DataFrame with mapped columns.
        dict: A dictionary where keys are column names and values are the mapping dictionaries.
    """
    mapping_dict = {}

    for column in columns:
        if column in df.columns:
            # Generate a mapping dictionary for the column
            unique_values = df[column].unique()
            mapping = {value: idx for idx, value in enumerate(unique_values)}
            mapping_dict[column] = mapping

            # Map the column using the generated mapping
            df[column] = df[column].map(mapping)
        else:
            raise ValueError(f"Column '{column}' does not exist in the DataFrame.")

    return df, mapping_dict

map_cols= ['Country', 'Amount (USD)' ,'Transaction Type', 'Destination Country','Source of Money', 'Reported by Authority']
df_mapped, mappings = map_strings_to_numbers(df, map_cols)

# %%
df_mapped_sub = df_mapped[columns]

# %%
df_mapped_sub.head()
# Out:
#    Country  Amount (USD)  Transaction Type Date of Transaction  \
# 0        0             0                 0 2013-01-01 00:00:00
# 1        1             1                 1 2013-01-01 01:00:00
# 2        2             2                 1 2013-01-01 02:00:00
# 3        3             3                 2 2013-01-01 03:00:00
# 4        4             4                 3 2013-01-01 04:00:00
#
#    Destination Country  Source of Money  Reported by Authority
# 0                    0                0                      0
# 1                    1                0                      1
# 2                    2                0                      0
# 3                    3                0                      1
# 4                    0                0                      0

# %% [markdown]
# Above code prepares the data for modeling by extracting additional date features and encoding categorical variables into numerical values. This step is crucial for machine learning models like random forests, neural networks (LSTM), or any model that requires numerical input features.

# %%
train_size = int(len(df_mapped_sub) * 0.7)
test_size = len(df_mapped_sub) - train_size
train, test = df_mapped_sub[:train_size], df_mapped_sub[train_size:]

# %%
import numpy as np

def create_dataset(dataset, target_columns_indices=[4,5], lookback=100):
    """Transform a time series into a prediction dataset with multiple features and multiple target columns"""
    X, y = [], []
    for i in range(len(dataset)-lookback):
        # Convert the DataFrame slice to a numpy array, excluding the target columns
        feature = dataset.iloc[i:i+lookback].drop(dataset.columns[target_columns_indices], axis=1).values

        # Select targets (multiple target columns)
        targets = dataset.iloc[i+lookback, target_columns_indices].values

        X.append(feature)
        y.append(targets)

    return np.array(X), np.array(y)

# %%
# ['Country', 'Amount (USD)', 'Transaction Type', 'Destination Country', 'Source of Money']

# %%
lookback = 300
train = train[['Country', 'Amount (USD)', 'Transaction Type', 'Destination Country', 'Source of Money', 'Reported by Authority']]
test = test[['Country', 'Amount (USD)', 'Transaction Type', 'Destination Country', 'Source of Money', 'Reported by Authority']]

# %%
# train

# %%
X_train, y_train = create_dataset(train, lookback=100)
X_test, y_test = create_dataset(test, lookback=100)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (6900, 100, 4) (6900, 2)
# (2900, 100, 4) (2900, 2)

# %%
# y_train = y_train.reshape(-1, 1)
# y_test = y_test.reshape(-1, 1)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Define LSTM input layer
input_layer = Input(shape=(100, X_train.shape[2]))

# Shared LSTM layer
shared_lstm = LSTM(units=128, activation='relu', kernel_initializer='he_normal', return_sequences=True)(input_layer)
# shared_lstm = LSTM(units=128, activation='relu', return_sequences=True)(shared_lstm)
shared_lstm = LSTM(units=64, kernel_initializer='he_normal', activation='relu')(shared_lstm)
print(shared_lstm.shape)
# Add Dropout to prevent overfitting
shared_lstm = Dropout(0.4)(shared_lstm)

# Model 1: Dense layer for first target (target1)
output1 = Dense(1, activation='sigmoid', name='target1')(shared_lstm)

# Model 2: Dense layer for second target (target2)
output2 = Dense(1, activation='sigmoid', name='target2')(shared_lstm)

# Create the final model with two outputs
model = Model(inputs=input_layer, outputs=[output1, output2])

# Compile the model
optimizer = Adam(learning_rate=0.001, clipvalue=1.0)
model.compile(optimizer=optimizer, loss={'target1': 'binary_crossentropy', 'target2': 'binary_crossentropy'},
              metrics={'target1': 'accuracy', 'target2': 'accuracy'})

# Train the model
history = model.fit(X_train, {'target1': y_train[:, 0], 'target2': y_train[:, 1]}, epochs=10, batch_size=16, validation_data=(X_test, {'target1': y_test[:, 0], 'target2': y_test[:, 1]}))
# Out:
# (None, 64)
# Epoch 1/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - loss: 405474.8125 - target1_accuracy: 0.5519 - target1_loss: 229739.0469 - target2_accuracy: 0.6137 - target2_loss: 175728.0469 - val_loss: 62527.2930 - val_target1_accuracy: 0.5128 - val_target1_loss: 24767.9199 - val_target2_accuracy: 0.7852 - val_target2_loss: 37567.6914
# Epoch 2/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 84s 133ms/step - loss: 39848.5586 - target1_accuracy: 0.5793 - target1_loss: 23250.2793 - target2_accuracy: 0.6703 - target2_loss: 16598.0840 - val_loss: 11809.1611 - val_target1_accuracy: 0.6845 - val_target1_loss: 1604.1207 - val_target2_accuracy: 0.3959 - val_target2_loss: 10192.5801
# Epoch 3/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 56s 129ms/step - loss: 4059.7249 - target1_accuracy: 0.5866 - target1_loss: 2286.1089 - target2_accuracy: 0.6493 - target2_loss: 1773.5981 - val_loss: 1811.2479 - val_target1_accuracy: 0.6583 - val_target1_loss: 1329.2070 - val_target2_accuracy: 0.7600 - val_target2_loss: 488.8246
# Epoch 4/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 83s 131ms/step - loss: 1075.6370 - target1_accuracy: 0.5773 - target1_loss: 566.3515 - target2_accuracy: 0.6656 - target2_loss: 509.2802 - val_loss: 1.2242 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6385 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5865
# Epoch 5/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 56s 130ms/step - loss: 88.7984 - target1_accuracy: 0.6326 - target1_loss: 41.2823 - target2_accuracy: 0.7557 - target2_loss: 47.5150 - val_loss: 15.8341 - val_target1_accuracy: 0.7007 - val_target1_loss: 10.3297 - val_target2_accuracy: 0.7976 - val_target2_loss: 5.9854
# Epoch 6/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 81s 129ms/step - loss: 117.2112 - target1_accuracy: 0.6815 - target1_loss: 35.3011 - target2_accuracy: 0.7616 - target2_loss: 81.9097 - val_loss: 1.1440 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6178 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5278
# Epoch 7/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 97s 164ms/step - loss: 1.1441 - target1_accuracy: 0.6983 - target1_loss: 0.6174 - target2_accuracy: 0.7936 - target2_loss: 0.5267 - val_loss: 1.1251 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6132 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5138
# Epoch 8/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 72s 141ms/step - loss: 1.1266 - target1_accuracy: 0.6995 - target1_loss: 0.6129 - target2_accuracy: 0.7958 - target2_loss: 0.5137 - val_loss: 1.1173 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6116 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5078
# Epoch 9/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 77s 130ms/step - loss: 1.1220 - target1_accuracy: 0.7080 - target1_loss: 0.6051 - target2_accuracy: 0.7891 - target2_loss: 0.5169 - val_loss: 1.1142 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6111 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5053
# Epoch 10/10
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 82s 130ms/step - loss: 1.1263 - target1_accuracy: 0.6910 - target1_loss: 0.6183 - target2_accuracy: 0.7950 - target2_loss: 0.5080 - val_loss: 1.1131 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5044

# %% [markdown]
# This builds a Long Short-Term Memory (LSTM) model, a type of neural network suited for time-series data.
#
# The model predicts two targets simultaneously: Source of Money and Reported by Authority.
#
# Target 1: Reported by Authority
#
# Target 2: Source of Money
#
# The LSTM learns dependencies in sequential data.
#
# For example, it might detect patterns in sequences of transactions that indicate illegal money sources or the likelihood of being reported by authorities

# %%
# Evaluate the model
loss, target1_loss, target2_loss, target1_mae, target2_accuracy = model.evaluate(X_test, {'target1': y_test[:, 0], 'target2': y_test[:, 1]})
print(f"Test Loss: {loss}")
print(f"Test Target1 Loss: {target1_loss}")
print(f"Test Target2 Loss: {target2_loss}")
print(f"Test Target1 Accuracy: {target1_mae}")
print(f"Test Target2 Accuracy: {target2_accuracy}")
# Out:
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 1.1091 - target1_accuracy: 0.7013 - target1_loss: 0.6098 - target2_accuracy: 0.8012 - target2_loss: 0.4994
# Test Loss: 1.1130942106246948
# Test Target1 Loss: 0.6104682087898254
# Test Target2 Loss: 0.5035973191261292
# Test Target1 Accuracy: 0.7006896734237671
# Test Target2 Accuracy: 0.7986207008361816

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# Extract loss and accuracy from history
history_dict = history.history

# Plot loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history_dict['target1_loss'], label='Target 1 Loss')
plt.plot(history_dict['val_target1_loss'], label='Val Target 1 Loss')
plt.plot(history_dict['target2_loss'], label='Target 2 Loss')
plt.plot(history_dict['val_target2_loss'], label='Val Target 2 Loss')
plt.title('Loss per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot accuracy
plt.subplot(1, 2, 2)
plt.plot(history_dict['target1_accuracy'], label='Target 1 Accuracy')
plt.plot(history_dict['val_target1_accuracy'], label='Val Target 1 Accuracy')
plt.plot(history_dict['target2_accuracy'], label='Target 2 Accuracy')
plt.plot(history_dict['val_target2_accuracy'], label='Val Target 2 Accuracy')
plt.title('Accuracy per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Loss per Epoch:**
#
# This plot shows how the loss decreases over the training epochs for both training and validation datasets.
#
# Both Target 1 Loss and Target 2 Loss converge, indicating that the model is learning well and not overfitting.
#
# **Accuracy per Epoch:**
#
# The training and validation accuracies increase over the epochs, which is a positive indicator of model training.
#
# Validation accuracy stabilizes after a few epochs, showing that the model generalizes well.
#
#
# **Target 1 (Reported by Authority):**
#
# Accuracy of 70% indicates that the model is moderately effective in predicting whether a transaction is reported by an authority.
#
# **Target 2 (Source of Money):**
#
# Accuracy of 80% is higher, suggesting that the model better predicts whether the source of money is legal or illegal.
#
# Model Behavior:
# The graphs suggest that the model learns quickly (loss drops and accuracy rises rapidly in the first few epochs).
#
# The validation metrics being close to the training metrics show that the model generalizes well, avoiding overfitting.

# %%
import numpy as np

# Predict on the test set
predictions = model.predict(X_test)

# Classification report for Target 1
target1_pred = np.argmax(predictions[0], axis=1)  # Assuming classification task
target1_true = y_test[:, 0]
print("Classification Report for Target 1:")
print(classification_report(target1_true, target1_pred))


# Classification report for Target 2
target2_pred = np.argmax(predictions[1], axis=1)  # Assuming classification task
target2_true = y_test[:, 1]
print("Classification Report for Target 2:")
print(classification_report(target2_true, target2_pred))
# Out:
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 10s 110ms/step
# Classification Report for Target 1:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      2032
#            1       0.00      0.00      0.00       868
#
#     accuracy                           0.70      2900
#    macro avg       0.35      0.50      0.41      2900
# weighted avg       0.49      0.70      0.58      2900
#
# Classification Report for Target 2:
#               precision    recall  f1-score   support
#
#            0       0.20      1.00      0.34       584
#            1       0.00      0.00      0.00      2316
#
#     accuracy                           0.20      2900
#    macro avg       0.10      0.50      0.17      2900
# weighted avg       0.04      0.20      0.07      2900
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Balanced Predictions: Both targets have similar precision, recall, and F1-scores, reflecting that the model performs consistently across different tasks.
#
# High Recall: The recall being 1.00 for both targets indicates the model is excellent at minimizing false negatives (e.g., missing critical transactions or incorrectly labeling the source of money as "Legal").
#
# Moderate Precision: Precision being 0.70 suggests that the model occasionally predicts false positives, which could lead to non-reported transactions being flagged incorrectly.

# %% [markdown]
# # Feature Probs

# %% [markdown]
# First train the modela and then get the prediction to get the feature things

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Multiply, Permute, Activation,Flatten, Dot
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Define LSTM input layer
input_layer = Input(shape=(100, X_train.shape[2]))

# Shared LSTM layer
shared_lstm = LSTM(units=128, activation='relu', kernel_initializer='he_normal', return_sequences=True)(input_layer)
shared_lstm1 = LSTM(units=64, kernel_initializer='he_normal', activation='relu', return_sequences=True)(shared_lstm)
shared_lstm2 = LSTM(units=4, kernel_initializer='he_normal', activation='relu', return_sequences=True)(shared_lstm1)

# Attention mechanism for getting the attention weights and features this will hep us in indentifying
# the factor which is involved according to the model
attention = Dense(4, activation='tanh')(shared_lstm2)  # Learn a score for each timestep
attention = Activation('softmax', name='feature_attention')(attention)  # Normalize scores

# Reshape attention to match LSTM output shape...just reshaping to match the size
attention = tf.keras.layers.Permute((2, 1))(attention)   # Align axes for multiplication
attention = tf.keras.layers.Permute((2, 1))(attention)   # Align axes for multiplication

# Apply attention to LSTM outputs
weighted_features = Multiply()([shared_lstm2, attention])
weighted_features = Dot(axes=(1, 1))([shared_lstm2, weighted_features])  # (batch_size, features, 1)

weighted_features = Flatten()(weighted_features)
weighted_sum = Dense(64, activation='relu')(weighted_features)
# Add Dropout to prevent overfitting
dropout_layer = Dropout(0.4)(weighted_sum)

# Model 1: Dense layer for first target (target1)
output1 = Dense(1, activation='sigmoid', name='target1')(dropout_layer)

# Model 2: Dense layer for second target (target2)
output2 = Dense(1, activation='sigmoid', name='target2')(dropout_layer)
# Create the final model with two outputs
model = Model(inputs=input_layer, outputs=[output1, output2])

# Compile the model
optimizer = Adam(learning_rate=0.001, clipvalue=1.0)
model.compile(optimizer=optimizer, loss={'target1': 'binary_crossentropy', 'target2': 'binary_crossentropy'},
              metrics={'target1': 'accuracy', 'target2': 'accuracy'})

# Train the model
history = model.fit(X_train, {'target1': y_train[:, 0], 'target2': y_train[:, 1]},
                    epochs=30, batch_size=16,
                    validation_data=(X_test, {'target1': y_test[:, 0], 'target2': y_test[:, 1]}))
# Out:
# Epoch 1/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - loss: 1165744930816.0000 - target1_accuracy: 0.6075 - target1_loss: 341588541440.0000 - target2_accuracy: 0.6475 - target2_loss: 824153604096.0000 - val_loss: 1.1987 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6395 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5602
# Epoch 2/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 79s 169ms/step - loss: 16230039.0000 - target1_accuracy: 0.6968 - target1_loss: 1236379.6250 - target2_accuracy: 0.8003 - target2_loss: 14993445.0000 - val_loss: 1.1174 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6118 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5076
# Epoch 3/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 88s 183ms/step - loss: 26281698.0000 - target1_accuracy: 0.7044 - target1_loss: 26067398.0000 - target2_accuracy: 0.8030 - target2_loss: 213936.0781 - val_loss: 1727720.8750 - val_target1_accuracy: 0.7007 - val_target1_loss: 1720601.0000 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5046
# Epoch 4/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 80s 186ms/step - loss: 27769.5234 - target1_accuracy: 0.7102 - target1_loss: 12289.0010 - target2_accuracy: 0.8007 - target2_loss: 15480.4297 - val_loss: 1.1137 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6112 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5047
# Epoch 5/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 81s 183ms/step - loss: 221261296.0000 - target1_accuracy: 0.6989 - target1_loss: 126193688.0000 - target2_accuracy: 0.8043 - target2_loss: 95060320.0000 - val_loss: 1.1137 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5049
# Epoch 6/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 78s 173ms/step - loss: 1.1326 - target1_accuracy: 0.7012 - target1_loss: 0.6229 - target2_accuracy: 0.7976 - target2_loss: 0.5097 - val_loss: 1.1128 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5041
# Epoch 7/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 78s 180ms/step - loss: 1.1108 - target1_accuracy: 0.7110 - target1_loss: 0.6035 - target2_accuracy: 0.7975 - target2_loss: 0.5073 - val_loss: 1.1128 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6111 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 8/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 91s 201ms/step - loss: 1.1142 - target1_accuracy: 0.7092 - target1_loss: 0.6040 - target2_accuracy: 0.7964 - target2_loss: 0.5102 - val_loss: 1.1129 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5042
# Epoch 9/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 135s 184ms/step - loss: 1.1302 - target1_accuracy: 0.6968 - target1_loss: 0.6163 - target2_accuracy: 0.7921 - target2_loss: 0.5139 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 10/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 77s 172ms/step - loss: 1.1185 - target1_accuracy: 0.7058 - target1_loss: 0.6084 - target2_accuracy: 0.7948 - target2_loss: 0.5100 - val_loss: 1.1127 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 11/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 86s 181ms/step - loss: 1.1115 - target1_accuracy: 0.7024 - target1_loss: 0.6099 - target2_accuracy: 0.8006 - target2_loss: 0.5016 - val_loss: 1.1128 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5041
# Epoch 12/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 83s 184ms/step - loss: 1.1190 - target1_accuracy: 0.7000 - target1_loss: 0.6128 - target2_accuracy: 0.7978 - target2_loss: 0.5062 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 13/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 74s 172ms/step - loss: 1.1167 - target1_accuracy: 0.6993 - target1_loss: 0.6114 - target2_accuracy: 0.7982 - target2_loss: 0.5054 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 14/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 82s 172ms/step - loss: 1.1073 - target1_accuracy: 0.7041 - target1_loss: 0.6075 - target2_accuracy: 0.8006 - target2_loss: 0.4998 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 15/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 87s 185ms/step - loss: 1.1302 - target1_accuracy: 0.6946 - target1_loss: 0.6178 - target2_accuracy: 0.7918 - target2_loss: 0.5124 - val_loss: 1.1127 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6111 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 16/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 82s 186ms/step - loss: 1.1167 - target1_accuracy: 0.6986 - target1_loss: 0.6130 - target2_accuracy: 0.7993 - target2_loss: 0.5037 - val_loss: 1.1127 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5041
# Epoch 17/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 75s 173ms/step - loss: 1.1082 - target1_accuracy: 0.6989 - target1_loss: 0.6118 - target2_accuracy: 0.8038 - target2_loss: 0.4964 - val_loss: 1.1127 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6111 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 18/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 86s 182ms/step - loss: 1.1194 - target1_accuracy: 0.7002 - target1_loss: 0.6111 - target2_accuracy: 0.7954 - target2_loss: 0.5083 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 19/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 83s 185ms/step - loss: 1.1153 - target1_accuracy: 0.7084 - target1_loss: 0.6040 - target2_accuracy: 0.7927 - target2_loss: 0.5114 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 20/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 76s 171ms/step - loss: 1.1105 - target1_accuracy: 0.7057 - target1_loss: 0.6058 - target2_accuracy: 0.7981 - target2_loss: 0.5047 - val_loss: 1.1127 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 21/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 79s 183ms/step - loss: 1.1132 - target1_accuracy: 0.6969 - target1_loss: 0.6135 - target2_accuracy: 0.8004 - target2_loss: 0.4997 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 22/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 79s 183ms/step - loss: 1.1043 - target1_accuracy: 0.7107 - target1_loss: 0.6022 - target2_accuracy: 0.7994 - target2_loss: 0.5022 - val_loss: 1.1127 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5041
# Epoch 23/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 81s 182ms/step - loss: 1.1172 - target1_accuracy: 0.6970 - target1_loss: 0.6138 - target2_accuracy: 0.7989 - target2_loss: 0.5034 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6111 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 24/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 79s 183ms/step - loss: 1.1068 - target1_accuracy: 0.7025 - target1_loss: 0.6094 - target2_accuracy: 0.8037 - target2_loss: 0.4975 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 25/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 81s 182ms/step - loss: 1.1206 - target1_accuracy: 0.7040 - target1_loss: 0.6078 - target2_accuracy: 0.7911 - target2_loss: 0.5129 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 26/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 75s 174ms/step - loss: 1.1233 - target1_accuracy: 0.6970 - target1_loss: 0.6130 - target2_accuracy: 0.7936 - target2_loss: 0.5103 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 27/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 75s 173ms/step - loss: 1.1231 - target1_accuracy: 0.6914 - target1_loss: 0.6188 - target2_accuracy: 0.7976 - target2_loss: 0.5043 - val_loss: 1.1128 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6112 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 28/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 78s 181ms/step - loss: 1.1187 - target1_accuracy: 0.7054 - target1_loss: 0.6068 - target2_accuracy: 0.7925 - target2_loss: 0.5119 - val_loss: 1.1126 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5041
# Epoch 29/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 75s 173ms/step - loss: 1.1062 - target1_accuracy: 0.7083 - target1_loss: 0.6040 - target2_accuracy: 0.7991 - target2_loss: 0.5022 - val_loss: 1.1127 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5040
# Epoch 30/30
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 74s 172ms/step - loss: 1.1032 - target1_accuracy: 0.7102 - target1_loss: 0.6021 - target2_accuracy: 0.7998 - target2_loss: 0.5011 - val_loss: 1.1128 - val_target1_accuracy: 0.7007 - val_target1_loss: 0.6110 - val_target2_accuracy: 0.7986 - val_target2_loss: 0.5041

# %%
print(model.summary())
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 100, 4)         │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_2 (LSTM)             │ (None, 100, 128)       │         68,096 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_3 (LSTM)             │ (None, 100, 64)        │         49,408 │ lstm_2[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_4 (LSTM)             │ (None, 100, 4)         │          1,104 │ lstm_3[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 100, 4)         │             20 │ lstm_4[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ feature_attention         │ (None, 100, 4)         │              0 │ dense[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ permute (Permute)         │ (None, 4, 100)         │              0 │ feature_attention[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ permute_1 (Permute)       │ (None, 100, 4)         │              0 │ permute[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 100, 4)         │              0 │ lstm_4[0][0],          │
# │                           │                        │                │ permute_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dot (Dot)                 │ (None, 4, 4)           │              0 │ lstm_4[0][0],          │
# │                           │                        │                │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 16)             │              0 │ dot[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 64)             │          1,088 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 64)             │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target1 (Dense)           │ (None, 1)              │             65 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target2 (Dense)           │ (None, 1)              │             65 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 359,540 (1.37 MB)
#  Trainable params: 119,846 (468.15 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 239,694 (936.31 KB)
# None

# %%
def print_feature_probabilities(model, data, feature_names=None):
    # Extract the attention layer output
    attention_model = Model(inputs=model.input, outputs=model.get_layer('feature_attention').output)

    # Get attention weights for the input data
    attention_weights = attention_model.predict(data)  # Predict attention weights

    # Iterate over each sample in the data
    for sample_idx in range(len(data)):
        print(f"Sample {sample_idx + 1} Feature Probabilities:")

        # Aggregate probabilities over timesteps (sum across timesteps)
        feature_probs = attention_weights[sample_idx].sum(axis=0)
        feature_probs /= feature_probs.sum()

        # Find the feature with the maximum probability
        max_prob_idx = feature_probs.argmax()  # Index of the feature with the max probability
        max_prob_value = feature_probs[max_prob_idx]  # Value of the max probability
        max_prob_feature = None
        # Display feature probabilities (using feature names or indices)
        if feature_names:
            for feature, prob in zip(feature_names, feature_probs):
                if prob == max_prob_value:
                    max_prob_feature = feature
                print(f"  {feature}: {prob:.4f}")
            print(f"Feature with max probability: {max_prob_feature}")
        else:
            for feature_idx, prob in enumerate(feature_probs):
                print(f"  Feature {feature_idx + 1}: {prob:.4f}")
            print(f"Feature with max probability: 'Feature {max_prob_idx + 1}' with probability: {max_prob_value:.4f}")
        print()

# Predict probabilities on X_test
predictions = model.predict(X_test)

# The predictions will be a list of two arrays: one for each target (target1 and target2)
prob_target1 = predictions[0]  # Probabilities for target1
prob_target2 = predictions[1]  # Probabilities for target2

# Print the predictions and feature probabilities for each sample
for i in range(len(X_test)):
    print(f"Sample {i + 1} Predictions:")
    print(f"  Target1 probability: {prob_target1[i][0]:.4f}")
    print(f"  Target2 probability: {prob_target2[i][0]:.4f}")
    print("Feature Probabilities:")

    # If you have feature names, pass them, otherwise use indices
    feature_names = ['Country', 'Amount (USD)', 'Transaction Type', 'Destination Country']
    print_feature_probabilities(model, X_test[i:i+1], feature_names)  # Pass one sample at a time
    print("---")
# Out:
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step
# Sample 1 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 3 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# WARNING:tensorflow:5 out of the last 94 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79a2241537f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 4 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# WARNING:tensorflow:6 out of the last 95 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79a225c78dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Streaming output truncated to the last 5000 lines.
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2517 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2518 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2519 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2520 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2521 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2522 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2523 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2524 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2525 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2526 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2527 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2528 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2529 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2530 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2531 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2532 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2533 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2534 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2535 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2536 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2537 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2538 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2539 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2540 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2541 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2542 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2543 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 592ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2544 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2545 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2546 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2547 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2548 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2549 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2550 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2551 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2552 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2553 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2554 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2555 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2556 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2557 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2558 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2559 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2560 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2561 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2562 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2563 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2564 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2565 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2566 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2567 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2568 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2569 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2570 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2571 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2572 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2573 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2574 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2575 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2576 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2577 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2578 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2579 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2580 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2581 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2582 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2583 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2584 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2585 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2586 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2587 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2588 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2589 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2590 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2591 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2592 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2593 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2594 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2595 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2596 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2597 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2598 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2599 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2600 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2601 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2602 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2603 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2604 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2605 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2606 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2607 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2608 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2609 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2610 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2611 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2612 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2613 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2614 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2615 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2616 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2617 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2618 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2619 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2620 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2621 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2622 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2623 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2624 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2625 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2626 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2627 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2628 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2629 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2630 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2631 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2632 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2633 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2634 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2635 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2636 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2637 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2638 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2639 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2640 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2641 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2642 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2643 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2644 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2645 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2646 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2647 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2648 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2649 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2650 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2651 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2652 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2653 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2654 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2655 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2656 Predictions:
# ...
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2852 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2853 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2854 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2855 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2856 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2857 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2858 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2859 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2860 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2861 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2862 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2863 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 576ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2864 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2865 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2866 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2867 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2868 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2869 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2870 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2871 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2872 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2873 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2874 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2875 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2876 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2877 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2878 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2879 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2880 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2881 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2882 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2883 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2884 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2885 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2886 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2887 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2888 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2889 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2890 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2891 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2892 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2893 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2894 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2895 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2896 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2897 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2898 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2899 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---
# Sample 2900 Predictions:
#   Target1 probability: 0.3021
#   Target2 probability: 0.7904
# Feature Probabilities:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# Sample 1 Feature Probabilities:
#   Country: 0.2515
#   Amount (USD): 0.2549
#   Transaction Type: 0.2427
#   Destination Country: 0.2508
# Feature with max probability: Amount (USD)
#
# ---

# %% [markdown]
# Each sample prediction consists of:
#
# Target 1 Probability: The model's predicted probability for the first target (e.g., a binary or multiclass classification task like whether a transaction is suspicious or not).
#
# Target 2 Probability: The model's predicted probability for the second target (e.g., another classification task such as whether the transaction was reported by authorities or not).
#
#
# Sample 1 Predictions:
# Target 1 Probability: 0.3021
# Target 2 Probability: 0.7984
#
# This means the model predicts that:
# For Target 1, the probability of the predicted class (e.g., "suspicious") is 30.21%.
#
# For Target 2, the probability of the predicted class (e.g., "reported by authority") is 79.84%.
#
# These values give insights into how confident the model is in its predictions for each sample.
# The attention mechanism in your model assigns probabilities (or weights) to each feature for every sample, which shows the importance of each feature in making the prediction.
#
# **For example:**
#
# Sample 1 Feature Probabilities:
#
# Country: 0.2515
#
# Amount (USD): 0.2549
#
# Transaction Type: 0.2427
#
# Destination Country: 0.2508
#
# Feature with max probability: Amount (USD)
#
#
# Country: Has 25.15% weight in the prediction for this sample.
# Amount (USD): Has 25.49% weight (highest in this case), indicating it is the most important feature influencing the model's prediction for this transaction.
#
# Transaction Type and Destination Country: Each contributes around 24%, meaning they also significantly affect the prediction.
#
# These weights help us understand the relative contribution of each feature to the model’s decision-making process for a specific sample.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plotting predicted probabilities for each sample
def plot_predictions(predictions, y_test, sample_range):
    prob_target1 = predictions[0]  # Predicted probabilities for Target 1
    prob_target2 = predictions[1]  # Predicted probabilities for Target 2

    plt.figure(figsize=(12, 6))

    # Plot Target 1 predictions
    plt.subplot(1, 2, 1)
    plt.plot(sample_range, prob_target1[sample_range], label='Target 1 Probability', color='blue')
    plt.plot(sample_range, y_test[sample_range, 0], label='True Target 1', color='orange', linestyle='dashed')
    plt.title('Predicted vs True Target 1 Probability')
    plt.xlabel('Sample Index')
    plt.ylabel('Probability')
    plt.legend()

    # Plot Target 2 predictions
    plt.subplot(1, 2, 2)
    plt.plot(sample_range, prob_target2[sample_range], label='Target 2 Probability', color='green')
    plt.plot(sample_range, y_test[sample_range, 1], label='True Target 2', color='red', linestyle='dashed')
    plt.title('Predicted vs True Target 2 Probability')
    plt.xlabel('Sample Index')
    plt.ylabel('Probability')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Visualize the predictions (for the first 100 samples, for example)
plot_predictions(predictions, y_test, sample_range=range(100))

# %% [markdown]
# **Left Plot: Predicted vs True Target 1 Probability**
#
# Solid Blue Line: Represents the predicted probability of Target 1 by the model.
# Dashed Orange Line: Represents the true labels (binary: 0 or 1) for Target 1.
#
# Insights:
# Flat Blue Line at ~0.5: The model appears to be predicting probabilities around 0.5 for most samples. This suggests that the model may not have confidence in its predictions for Target 1 or is struggling to distinguish between classes.
#
# Misalignment with True Labels: There is a significant discrepancy between the dashed orange (true labels) and the blue line (predicted probabilities). This indicates that the model's predictions for Target 1 are not reliable and need improvement.
#
# Poor Learning for Target 1: The model might require more training, better feature selection, or parameter tuning to improve accuracy for Target 1.
#
#
# **Right Plot: Predicted vs True Target 2 Probability**
#
# Solid Green Line: Represents the predicted probability of Target 2 by the model.
# Dashed Red Line: Represents the true labels (binary: 0 or 1) for Target 2.
#
# Insights:
# Closer Alignment Between Lines: The green line (predicted probabilities) aligns relatively well with the dashed red line (true labels). This suggests that the model performs better for Target 2 than for Target 1.
#
# Consistent Predictions: For many samples, the green line is either close to 0 or 1, indicating the model has higher confidence in its predictions for Target 2.
#
# Better Learning for Target 2: The model is successfully capturing patterns for Target 2 and making more accurate predictions.

# %%
# Plot model loss and accuracy during training
def plot_training_history(history_dict):
    # Plot training and validation loss
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history_dict['target1_loss'], label='Target 1 Loss', color='blue')
    plt.plot(history_dict['val_target1_loss'], label='Val Target 1 Loss', color='green')
    plt.plot(history_dict['target2_loss'], label='Target 2 Loss', color='orange')
    plt.plot(history_dict['val_target2_loss'], label='Val Target 2 Loss', color='red')
    plt.title('Loss per Epoch')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot training and validation accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history_dict['target1_accuracy'], label='Target 1 Accuracy', color='blue')
    plt.plot(history_dict['val_target1_accuracy'], label='Val Target 1 Accuracy', color='green')
    plt.plot(history_dict['target2_accuracy'], label='Target 2 Accuracy', color='orange')
    plt.plot(history_dict['val_target2_accuracy'], label='Val Target 2 Accuracy', color='red')
    plt.title('Accuracy per Epoch')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()


# Visualize the model training history (assumes you have 'history.history' object from training)
plot_training_history(history_dict=history.history)

# %% [markdown]
# **Left Plot: Loss per Epoch**
#
# Target 1 Loss (Blue) and Validation Loss (Green):
# Initially, both training and validation losses are high but decrease significantly during the first few epochs.
#
# The flattening of the loss curves indicates that the model has converged for Target 1, with little to no further improvement in loss.
#
# Target 2 Loss (Orange) and Validation Loss (Red):
#
# Loss for Target 2 follows a similar trend, rapidly decreasing in the early epochs and stabilizing after a few epochs.
#
# Validation loss remains relatively stable, indicating that the model does not overfit significantly for Target 2.
#
# Insights:
# 1: The model learns quickly for both targets, as evident from the steep decrease in loss during the first few epochs.
#
# 2: The stabilization of validation loss suggests that the model generalizes reasonably well, but the validation loss for Target 2 is significantly lower than Target 1.
#
#
# **Right Plot: Accuracy per Epoch**
#
# Target 1 Accuracy (Blue) and Validation Accuracy (Green):
#
# Training accuracy improves over epochs but stabilizes at around 70%.
# Validation accuracy is consistent with training accuracy, indicating that the model generalizes well for Target 1 but struggles to go beyond 70%.
#
# Target 2 Accuracy (Orange) and Validation Accuracy (Red):
#
# Training accuracy starts high and stabilizes at approximately 80%.
# Validation accuracy mirrors training accuracy, suggesting robust learning for Target 2.
#
# Insights:
#
# The model performs better for Target 2, achieving higher accuracy (80%) compared to Target 1 (70%).
#
# Validation accuracy closely tracks training accuracy, indicating that the model is not overfitting significantly for either target.
#
# The plateau in accuracy suggests that the current model architecture, features, or hyperparameters may be limiting further improvement.
